# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Replace 'data' with the folder name where your file is located
file_path = '/content/drive/My Drive/df_top_20_movies_customers_reviewed_all.csv'

# Read the CSV file
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Movie_Id  Cust_Id  Rating        Date  Movie_Year             Name  \
# 0       571  1844276     5.0  2002-03-05        1999  American Beauty
# 1       571  2422606     1.0  2001-11-20        1999  American Beauty
# 2       571  1515501     3.0  2002-11-25        1999  American Beauty
# 3       571   181323     4.0  2002-01-22        1999  American Beauty
# 4       571   243963     4.0  2002-02-26        1999  American Beauty
#
#    Average_Rating  Review_Count
# 0        3.962585        154832
# 1        3.962585        154832
# 2        3.962585        154832
# 3        3.962585        154832
# 4        3.962585        154832

# %%
import openai
import pandas as pd
import json

# Define your OpenAI API key
openai.api_key = 'sk-proj-6aKnOuK9WOluCm7G4NcpT3BlbkFJPe4m3YD9OngGAkTTLbJw'

# Function to create a prompt for the LLM
def create_prompt(user_id, user_ratings):
    prompt = f"Based on the following movie ratings by user {user_id}, recommend some similar movies:\n"
    for rating in user_ratings:
        prompt += f"- {rating['Name']}: {rating['Rating']} stars\n"
    prompt += "Recommend similar movies that the user might like."
    return prompt

# Function to get recommendations from ChatGPT
def get_chatgpt_recommendation(prompt):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a movie recommendation assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=150
    )
    return response.choices[0].message['content'].strip()

# Example user ID
user_id = 1844276  # Replace with actual Cust_Id

# Get user ratings
user_ratings = df[df['Cust_Id'] == user_id][['Name', 'Rating']].to_dict(orient='records')

# Create the prompt
prompt = create_prompt(user_id, user_ratings)

# Get movie recommendations from ChatGPT
chatgpt_recommendation = get_chatgpt_recommendation(prompt)
print("ChatGPT Recommendation:", chatgpt_recommendation)
# Out:
# ChatGPT Recommendation: Based on user 1844276's movie ratings, here are some recommendations for similar movies you might like:
#
# 1. **Eternal Sunshine of the Spotless Mind**: A thought-provoking drama with elements of romance and psychological exploration.
#
# 2. **Fight Club**: A dark and intense film with a twist that challenges societal norms and perceptions.
#
# 3. **Inception**: A mind-bending thriller that explores the depths of dreams and reality.
#
# 4. **The Shawshank Redemption**: A powerful and inspirational drama about hope and redemption.
#
# 5. **The Prestige**: A suspenseful and intricate mystery about rival magicians.
#
# 6. **The Departed**: A gripping crime thriller with twists and turns set in the world of organized crime.

# %%
# !pip install openai==0.28
